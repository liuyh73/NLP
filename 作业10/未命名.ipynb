# %%
# -*- coding: utf-8 -*-
import re
import math
import string
import jieba
import jieba.posseg as pseg

N = 193

# %% [markdown]
# **filter_punctuation:**去除单词中的符号。

# %%
def filter_punctuation(words):
    new_words=[]
    illegal_char = string.punctuation + u'-\n.,;《》？！“”‘’@#￥%…&×（）——+【】{};；●，。&～、|\s:：'
    pattern = re.compile('[%s]'%re.escape(illegal_char))
    for word in words:
        new_word = pattern.sub(u'',word)
        if not new_word == u'':
            new_words.append(new_word)
    return new_words

# %% [markdown]
# **load_word_list:**从文件中加载单词。

# %%
def load_word_list():
    word_list = [[] for i in range(0,N+1)]
    word_set = set()
    for i in range(1,N+1):
        with open('./page/'+ str(i) +'.txt',encoding='utf-8',errors='ignore') as f:
            for line in f.readlines():
                filter_punctuation_words = filter_punctuation(jieba.cut(line))
                for filter_punctuation_word in filter_punctuation_words:
                    word_set.add(filter_punctuation_word)
                word_list[i].extend(filter_punctuation_words)
                # print(word_list[i])
    print(len(word_set))
    return word_list, word_set

# %% [markdown]
# **build_inverted_index:**构造倒排索引。

# %%
def build_inverted_index(word_list, word_set):
    inverted_index = {}
    for word in word_set:
        indices = []
        for i in range(1,N+1):
            count = 0
            for w in word_list[i]:
                if w == word:
                    count+=1
            indices.append({
                "page": i,
                "count": count
            })
        inverted_index[word]=indices
    with open('inverted_index.txt', 'w', encoding='utf-8') as f:
        f.write(str(inverted_index))
    return inverted_index

# %% [markdown]
# **min_distance:**计算单词最短编辑距离。

# %%
def min_distance(word1, word2):
    m = len(word1) + 1
    n = len(word2) + 1
    dp = [[0 for j in range(n)] for i in range(m)]

    for i in range(m):
        dp[i][0]=i
    for j in range(n):
        dp[0][j]=j

    for i in range(1, m):
        for j in range(1, n):
            if word1[i-1] == word2[j-1]:
                dp[i][j] = dp[i-1][j-1]
            else:
                # 插入、删除、替换
                dp[i][j] = min(dp[i][j-1], dp[i-1][j], dp[i-1][j-1]) + 1

    return dp[m-1][n-1]

def spell_check(search, word_set, inverted_index):
    minn = 99999999
    similar_word = ""
    for word in word_set:
        dis = min_distance(search, word)
        if dis < minn:
            minn = dis
            similar_word = word
    return similar_word

# %% [markdown]
# **tf_idf:**计算td/idf值。

# %%
def tf_idf(word_set, inverted_index):
    word_td_idf = {} 
    for word in word_set:
        wtd = []
        num = 0
        for file in inverted_index[word]:
            if file["count"] > 0:
                num+=1
        for file in inverted_index[word]:
            wtd.append({
                "page": file["page"],
                "wtd": math.log(1+file["count"], 10)*math.log(N/num,10)
            })
        word_td_idf[word]=wtd
    return word_td_idf

# %%
word_list, word_set = load_word_list()
print(word_set)
# Out:
# 49628
# {'CLI', '顶天立地', '应用软件', '非迹', '联合开发', '艰苦', '选点', '拉丁字母', 'Territorial', '龙纳', '渊博', '智商', '冬天', '刘易斯', '叩', 'A', '美墨', '7062', '恐龙', '推理方法', '被误', '书店', '李伟生', '王兆其', '打', 'Sb', '政府首脑', '渗', '批量生产', '具体方法', '21789', '探讨', '54100', '分批', '材料', '参众', '罢了', '顺畅', '载入', '信道编码', '辩证唯物主义', '士大夫', 'Public', '翻译', '氯仿', '物以类聚', '太高', '体育场馆', '姜澜', '君主政体', 'Patton', '811001', '内部', '有病', '风趣', '阿奇博尔德', '风疹', '细胞融合', '毕业典礼', '症候', '四强赛', '一州时', '布克奖', '钐', '庄园', '体总', '完好无损', '昆仑山', '项部', '高寒', '远近', '莫泽', '首创', '意在', 'had', '两女一男', '你会', '完全一致', '分计', '演变', '我校', '物等', '666', '神秘化', '核芯', '高大', '比为', 'complete', '1607', '及近', '拜', '战平', '鳔', '宁静', '立场', '阿默斯', '王泽山', '浙赣', '触须', '雄黄', '沈家', '交通事故', '短语', '百科全书式', 'unimaginative', '侵蚀作用', '磨难', '吕', '宇多田光', '舍勒', '174cm', '病菌', '1775', '730', 'TheGathering', '爱宝', '测毒', '毒力', '城乡居民', '登记器', '怎么', '女主人', '金涌', '该所', '球极', '武装', '直属', '670', 'TIM', '干得', '胜过', 'Intenive', 'Cole', '达美', '单纯形', '煤气化', '外科', 'Google', '墨西哥人', '直通', '契机', '清扫', 'GAUSF', '求是', '赛', 'Numine', '请参阅', '诗篇', '徐遐生', '当脑', '重道', '春季', '截止', '福建省', 'RGB', '桑德拉', '魔杖', '分析方法', '赫章', 'Student', '增加', '主观能动', '卢万', '麦克米兰', '拓广', '科主任', 'huh', '中国建设银行', '引人注目', '德里达', '哪几种', '常数', '门缝', 'Rabbit', '王卫东', '对脑', '冬则', '657', '四域', '岸然', '不太难', 'equation', '转投', '行之有效', '布洛', '情报', 'Gil', '波利尼西亚', '此用', '聂', '负累', '王平', '经济危机', '交通网', '数据通信', '折', 'Nathan', '曹丕', '进驻', '纬度', '集约型', '新品', '纯色', '瓶子', '宝鉴', '油状', '尽责', '语言', '0928', '富强', '迦叶摩腾', '三亚', '原副', '用以', 'ὤ', '送交', '竞秀', '全面实现', '221', '总参', '硬道理', '志愿', '非凡', 'Technology', '证章', '它集', '决心', '15ml', '庄辉', 'individual', '并用', '科研成果', '但是', '腐蚀', '搅乱', '千年', '博尔顿', '私立学校', '乱', '风速', '育空', '互补性', '初具', 'Price', '信科', '盆地', 'itting', 'Burarie', '刘元安', 'Natural', 'Embedded', 'Concord', '非全日制', '研究型', '古根汉', '犯罪活动', 'Threholding', '10MB', '概率', '王阳明', '随机因素', '窗式空调', '世事', '位高权', '几次', '如钙', '1952', '①', '较之', '油脂', '马兴瑞', '有道是', '傅统先', '坐于', '巴', '明辨', '七七事变', '维勒', '朝着', '内布拉斯加州', '投资总额', '东亚人', 'Vigneaud', '佤', '外', '邹至庄', '脚比路长', '臭棋', '柏拉图', '歌舞团', '地算', 'Cup', '酒吧', '研制者', 'getting', 'Communication', '外膜', '作曲者', '果', '爆炸式', '133', '党的基本', 'Sing', '上锁', '698', 'good', '三维空间', 'Pollack', '藩国', '改革家', '孙正', '23940', '怎样', 'NH3', 'Q66', '飞扬跋扈', 'Moe', '运货', '价值论', '椎管', 'Blonde', '副董事长', '车夫', '随机化', '京汉铁路', '味蕾', '蒙昧', '遭遇', 'Ljup', '有带', '持续一年', 'SOLVING', '诊断', '不可知论', '郝', '科学基金', '10001', '查准率', '汉译', '阿童木', '农药', '遥远', '种子', '成求', 'reaoning', '中国民主同盟', '迭出', '比寒时', '综合型', '十字路口', '地缘', '未知领域', '平均误差', '温暖', 'Computerized', '资历', '执行机构', '不分', 'VII', '狭长', '朱继华', '激发起', '祝禁', '纳吉', '骨质', '1900', '5100', '隐马尔柯夫', '不具', 'WALTER', '地理坐标', '和胞体', '合众社', '动用', '地雷', 'Antonia', '巴克拉', '之术', '之为', '纺织机', '条', '内蕴', '翔实', '契约', '严苛', '回族', 'Golgi', '性取向', '学界', '清白', '清明', 'SSCI', '长堤', '批文', '假如', '可见度', '筹备组', '哈兰', 'Equinox', '900MHz', '导湿', '造纸厂', '文献', 'bridge', '无比', 'Birgeneau', '外倾', '对象化', '那时', '17580', '库中', '第十五', '上皮', '市区', '地想列', '热敏', '随身', '管庄', '物理', '低者', '利根', 'who', '官商', '弓箭', '班次', '独尊', '要拿够', '格言', '战火', '干', '一札', '互操作性', '是不是', '校长', 'Bartlett', '眼球', '月亮', '法国巴黎大学', '上起', '金融学', '虚词', '副产品', '钢结构', 'Niemeyer', '1938', '哈拉尔', '6657', '朱棣文', '制冷量', '丧生', '演讲比赛', '珀尔', '经济学家', '组成', 'B8', '责任心', '万英镑', '宣战', '80286', '顺序', '索利', '徐志明', 'ping', '深得', 'Delphi', '二义性', '斯瓦拉', '程幼金', '轮式', '劳动改造', '交往', '军事政变', '世界大国', '郭象注', '受热', '』', 'Marouf', '沿东', '边角', '发表演说', '渤', '特征值', '审批同意', '超平面', '鲁', '带宽', '转导', '得票数', '哨声', '二军', '科索沃', '同日而语', 'difference', '萨特', '1892', '张云泉', '旗袍', '迪肯逊', '等于零', '医学纲目', '四人帮', '高架桥', '万国', '做事', '平常', '计划周密', '飞利浦公司', 'tructure', '宗旨', '土著人', '276', '猛将', '不失为', '气胶', 'Artificialperception', '燕京大学', 'Bakhit', '积聚', '材', '断章取义', '读取器', '被控', '奉系军阀', '性能', '极端', '众山', '顶端', '感性认识', '数控系统', '汤姆', '伊朗核', '筹措', '超级计算机', '周遭', 'Timmy', '虚拟人', '小约翰', '累累', '转向架', 'Morgan', '主辅修制', '100nm', '泌尿系统', '逐臭之夫', '张翔', 'Macintoh', '相连', '高贵', '良好开端', '苯丙', '播出', '未定', '跨学科', '不当', '电压', '人力', '粗犷', '机作', '两面', '暴徒', '梅尔文德弗勒', '四核' ...

# %%
inverted_index = build_inverted_index(word_list, word_set)
# print(inverted_index)

# %%
word_td_idf = tf_idf(word_set, inverted_index)
# print(word_td_idf)

# %%
search = input("请输入你想查询的内容：")
search_words = jieba.cut(search)
page_scores = [0 for i in range(0,N+1)]
for search_word in search_words:
    similar_word = spell_check(search_word, word_set, inverted_index)
    for i in range(1,N+1):
        page_scores[i]+=word_td_idf[similar_word][i-1]["wtd"]
    
ranked_pages=[]
for i in range(1,N+1):
    ranked_pages.append({
        "page":i,
        "score":page_scores[i]
    })

ranked_pages = sorted(ranked_pages, key=lambda page: page["score"], reverse=True)
print(ranked_pages)
# ranked_pages = sorted(page_scores, reverse=True)
# print(similar_word, ":", ranked_pages[0:5])
# Out:
# 请输入你想查询的内容：化学方向的科研成果
# [{'page': 28, 'score': 1.7385759331221347}, {'page': 147, 'score': 1.6201516021392137}, {'page': 186, 'score': 1.487404374797843}, {'page': 91, 'score': 1.4872254519328267}, {'page': 21, 'score': 1.0531054529365669}, {'page': 117, 'score': 1.0531054529365669}, {'page': 89, 'score': 0.9323057815537351}, {'page': 97, 'score': 0.9077674383318927}, {'page': 64, 'score': 0.8990316710389047}, {'page': 156, 'score': 0.8705749855571069}, {'page': 68, 'score': 0.7997074228875658}, {'page': 62, 'score': 0.7995629295256994}, {'page': 159, 'score': 0.7978623246560825}, {'page': 170, 'score': 0.7641862107223044}, {'page': 188, 'score': 0.7188632746634531}, {'page': 98, 'score': 0.7108569618340719}, {'page': 74, 'score': 0.6905878758299913}, {'page': 67, 'score': 0.6833642000365661}, {'page': 54, 'score': 0.6645640611564319}, {'page': 3, 'score': 0.6458793424005238}, {'page': 168, 'score': 0.6326289480127465}, {'page': 115, 'score': 0.6055141384217795}, {'page': 155, 'score': 0.5944111036303869}, {'page': 61, 'score': 0.5936280788175269}, {'page': 111, 'score': 0.5620075280379875}, {'page': 126, 'score': 0.5531307049060094}, {'page': 179, 'score': 0.5252608058742956}, {'page': 174, 'score': 0.48685156509144734}, {'page': 41, 'score': 0.48677489333641644}, {'page': 70, 'score': 0.47694750915580003}, {'page': 57, 'score': 0.4764776219042466}, {'page': 104, 'score': 0.449638174853906}, {'page': 141, 'score': 0.43825224274926683}, {'page': 173, 'score': 0.4377044053175438}, {'page': 134, 'score': 0.4336084013949811}, {'page': 151, 'score': 0.42396239926837315}, {'page': 77, 'score': 0.4106485037122566}, {'page': 93, 'score': 0.4106485037122566}, {'page': 63, 'score': 0.39716098125577226}, {'page': 135, 'score': 0.39666830559967425}, {'page': 15, 'score': 0.3709802432198399}, {'page': 4, 'score': 0.37081357284248107}, {'page': 128, 'score': 0.3684083923660995}, {'page': 69, 'score': 0.34830723409384823}, {'page': 152, 'score': 0.3336566837885305}, {'page': 7, 'score': 0.3186218884956519}, {'page': 108, 'score': 0.27882465642956455}, {'page': 167, 'score': 0.2775787181365805}, {'page': 87, 'score': 0.27697178492144414}, {'page': 162, 'score': 0.276958807205534}, {'page': 6, 'score': 0.2769482998316263}, {'page': 94, 'score': 0.2751953655480885}, {'page': 148, 'score': 0.2751632379738785}, {'page': 44, 'score': 0.255186290860003}, {'page': 165, 'score': 0.2550349195216333}, {'page': 83, 'score': 0.25498453910314994}, {'page': 122, 'score': 0.2549820741880717}, {'page': 35, 'score': 0.25432489047416995}, {'page': 71, 'score': 0.2540019479602853}, {'page': 73, 'score': 0.2399548091619697}, {'page': 95, 'score': 0.23990793370112717}, {'page': 130, 'score': 0.23990793370112717}, {'page': 85, 'score': 0.23963650923172555}, {'page': 90, 'score': 0.23901314542777785}, {'page': 143, 'score': 0.23876315987796282}, {'page': 146, 'score': 0.23753569867894642}, {'page': 12, 'score': 0.23695300273574252}, {'page': 176, 'score': 0.19135421307287745}, {'page': 123, 'score': 0.19111404129752207}, {'page': 158, 'score': 0.19109927541508057}, {'page': 185, 'score': 0.1907597729487081}, {'page': 120, 'score': 0.1906880860611916}, {'page': 51, 'score': 0.19034735283571114}, {'page': 34, 'score': 0.1902410631516542}, {'page': 190, 'score': 0.1902046737037092}, {'page': 100, 'score': 0.1893330187224271}, {'page': 113, 'score': 0.16309950127744555}, {'page': 119, 'score': 0.1630247444918249}, {'page': 125, 'score': 0.16298380680997412}, {'page': 26, 'score': 0.1627114687513685}, {'page': 72, 'score': 0.16228085690720778}, {'page': 184, 'score': 0.16228085690720778}, {'page': 149, 'score': 0.1621492572454134}, {'page': 157, 'score': 0.16189951299672675}, {'page': 84, 'score': 0.16139372243131261}, {'page': 31, 'score': 0.16138039156952488}, {'page': 181, 'score': 0.16066012706763708}, {'page': 178, 'score': 0.12331093753590178}, {'page': 166, 'score': 0.12307373915911997}, {'page': 182, 'score': 0.12278602725635113}, {'page': 53, 'score': 0.122653974863487}, {'page': 22, ...

# %% [markdown]
# 实现方法中，自行实现拼写检查（spell_check），倒排索引（build_inverted_index），使用TF/IDF进行文档排序（tf_idf）。输入内容首先进行分词处理，然后使用spell_check来查找距离分词结果最近的单词，使用倒排索引求得tf/idf值，之后将输入所有分词后单词的td/idf值相加后进行排序，输出文档序号。其中使用的tf计算公式为：log10(1+tf)，idf计算公式为：log10(N/df)。
